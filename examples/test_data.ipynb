# %%
from mb.finetune.config import FinetuneConfig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mb.finetune.config import FinetuneConfig
#
# ModuleNotFoundError: No module named 'mb.finetune.config'

# %%
FinetuneConfig?
